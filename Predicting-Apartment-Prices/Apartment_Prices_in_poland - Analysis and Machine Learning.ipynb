# %% [markdown]
# #### Author: Victor Diallen Andrade do Amaral

# %% [markdown]
# # Table of Contents :
# * [1. Introduction](#section1)
# * [2. Importing Libraries](#section2)
# * [3. Loading Datasets](#section3)
# * [4. Data Analysis](#section4)
# * [5. Data Visualization](#section5)
# * [6. Machine Learning](#section6)
# * [7. Conclusion](#section7)

# %% [markdown]
# <a id="section1"></a>
# # Introduction

# %% [markdown]
# ## Kaggle Dataset Link

# %% [markdown]
# https://www.kaggle.com/datasets/krzysztofjamroz/apartment-prices-in-poland?select=apartments_pl_2023_10.csv

# %% [markdown]
# ## About Dataset
#
# The dataset contains apartment offers from the 15 largest cities in Poland (Warsaw, Lodz, Krakow, Wroclaw, Poznan, Gdansk, Szczecin, Bydgoszcz, Lublin, Katowice, Bialystok, Czestochowa). The data comes from local websites with apartments for sale. To fully capture the neighborhood of each apartment better, each offer was extended by data from the Open Street Map with distances to points of interest (POI). The data is collected monthly and covers timespan between September 2023 and October 2023

# %% [markdown]
# ## Variables Description
#
# - **city** - the name of the city where the property is located
# - **type** - type of the building
# - **squareMeters** - the size of the apartment in square meters
# - **rooms** - number of rooms in the apartment
# - **floor** / floorCount - the floor where the apartment is located and the total number of floors in the building
# - **buildYear** - the year when the building was built
# - **latitude, longitude** - geo coordinate of the property
# - **centreDistance** - distance from the city centre in km
# - **poiCount** - number of points of interest in 500m range from the apartment (schools, clinics, post offices, kindergartens, -  - - restaurants, colleges, pharmacies)
# - **[poiName]Distance** - distance to the nearest point of interest (schools, clinics, post offices, kindergartens, restaurants, colleges, pharmacies)
# - **ownership** - the type of property ownership
# - **condition** - the condition of the apartment
# - **has[features]** - whether the property has key features such as assigned parking space, balcony, elevator, security, storage room
# - **price** - offer price in Polish Zloty

# %% [markdown]
# <a id="section2"></a>
# # Importing Libraries

# %%
# Python version used
from platform import python_version
print('Python Version Used in this Jupyter Notebook:', python_version())
# Out:
# Python Version Used in this Jupyter Notebook: 3.9.7

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import permutation_importance
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.pipeline import make_pipeline
from scipy.stats import skew
from sklearn.linear_model import LinearRegression, Ridge, LassoCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import log_loss, accuracy_score
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from xgboost.sklearn import XGBRegressor
from sklearn.model_selection import RepeatedKFold
from numpy import absolute
import graphviz
import xgboost as xgb

# %%
# Libraries versions used in this jupyter notebook
# %reload_ext watermark
# %watermark -a "Victor Diallen Andrade do Amaral" --iversions
# Out:
# Author: Victor Diallen Andrade do Amaral
#
# seaborn   : 0.13.0
# numpy     : 1.23.0
# xgboost   : 2.0.0
# matplotlib: 3.8.0
# graphviz  : 0.20.1
# pandas    : 2.1.1
# sklearn   : 1.3.1

# %% [markdown]
# <a id="section3"></a>
# # Loading Datasets

# %%
df_august = pd.read_csv('apartments_august_2023.csv')
df_september = pd.read_csv('apartments_september_2023.csv')
df_october = pd.read_csv('apartments_october_2023.csv')

# %%
df_august.head()
# Out:
#                                  id      city          type  squareMeters  \
# 0  f8524536d4b09a0c8ccc0197ec9d7bde  szczecin  blockOfFlats         63.00
# 1  accbe77d4b360fea9735f138a50608dd  szczecin  blockOfFlats         36.00
# 2  8373aa373dbc3fe7ca3b7434166b8766  szczecin      tenement         73.02
# 3  0a68cd14c44ec5140143ece75d739535  szczecin      tenement         87.60
# 4  f66320e153c2441edc0fe293b54c8aeb  szczecin  blockOfFlats         66.00
#
#    rooms  floor  floorCount  buildYear   latitude  longitude  ...  \
# 0    3.0    4.0        10.0     1980.0  53.378933  14.625296  ...
# 1    2.0    8.0        10.0        NaN  53.442692  14.559690  ...
# 2    3.0    2.0         3.0        NaN  53.452222  14.553333  ...
# 3    3.0    2.0         3.0        NaN  53.435100  14.532900  ...
# 4    3.0    1.0         3.0        NaN  53.410278  14.503611  ...
#
#    pharmacyDistance    ownership  buildingMaterial  condition  \
# 0             0.413  condominium      concreteSlab        NaN
# 1             0.205  cooperative      concreteSlab        NaN
# 2             0.280  condominium             brick        NaN
# 3             0.087  condominium             brick        NaN
# 4             0.514  condominium               NaN        NaN
#
#    hasParkingSpace  hasBalcony  hasElevator  hasSecurity  hasStorageRoom  \
# 0              yes         yes          yes           no             yes
# 1               no         yes          yes           no             yes
# 2               no          no           no           no              no
# 3              yes         yes           no           no             yes
# 4               no          no           no           no              no
#
#     price
# 0  415000
# 1  395995
# 2  565000
# 3  640000
# 4  759000
#
# [5 rows x 28 columns]

# %%
df_september.head()
# Out:
#                                  id      city          type  squareMeters  \
# 0  71de9eb8a92ac12d7c94315228b70cfb  szczecin      tenement        123.45
# 1  23d558163bb1c7863c73485048e50858  szczecin           NaN         53.80
# 2  3b8819c6c9ffd55adfddfd5bafcc844d  szczecin      tenement         50.00
# 3  708ccd264180315a4cfe6324ed4861d0  szczecin  blockOfFlats         55.19
# 4  8373aa373dbc3fe7ca3b7434166b8766  szczecin      tenement         73.02
#
#    rooms  floor  floorCount  buildYear   latitude  longitude  ...  \
# 0    4.0    2.0         3.0        NaN  53.432586  14.535685  ...
# 1    2.0    5.0         5.0        NaN  53.429429  14.554642  ...
# 2    2.0    NaN         1.0        NaN  53.364400  14.660900  ...
# 3    2.0    1.0         2.0     2013.0  53.480364  14.541494  ...
# 4    3.0    2.0         3.0        NaN  53.452222  14.553333  ...
#
#    pharmacyDistance    ownership  buildingMaterial  condition  \
# 0             0.321  condominium             brick        NaN
# 1             0.073  cooperative               NaN        NaN
# 2             0.399  condominium             brick        NaN
# 3             0.183  condominium             brick    premium
# 4             0.280  condominium             brick        NaN
#
#    hasParkingSpace  hasBalcony  hasElevator  hasSecurity  hasStorageRoom  \
# 0               no         yes           no           no             yes
# 1               no          no          yes           no              no
# 2              yes          no           no           no              no
# 3              yes         yes           no          yes             yes
# 4               no          no           no           no              no
#
#     price
# 0  799000
# 1  420000
# 2  350000
# 3  607000
# 4  565000
#
# [5 rows x 28 columns]

# %%
df_october.head()
# Out:
#                                  id      city               type  \
# 0  23d558163bb1c7863c73485048e50858  szczecin                NaN
# 1  8373aa373dbc3fe7ca3b7434166b8766  szczecin           tenement
# 2  ede1c0d953ff85f3cd9676d39ca8f62d  szczecin       blockOfFlats
# 3  6c807c6c86a74c57a3fd4445a1f49a46  szczecin  apartmentBuilding
# 4  bb14c9a540275da73f6cb6ed42e5c26c  szczecin  apartmentBuilding
#
#    squareMeters  rooms  floor  floorCount  buildYear   latitude  longitude  \
# 0         53.80    2.0    5.0         5.0        NaN  53.429429  14.554642
# 1         73.02    3.0    2.0         3.0        NaN  53.452222  14.553333
# 2         37.00    2.0    8.0        10.0     1970.0  53.442692  14.559690
# 3         48.00    2.0    4.0         6.0        NaN  53.435461  14.570436
# 4         55.19    2.0    1.0         2.0     2013.0  53.482094  14.542574
#
#    ...  pharmacyDistance    ownership  buildingMaterial  condition  \
# 0  ...             0.073  cooperative               NaN        NaN
# 1  ...             0.280  condominium             brick        NaN
# 2  ...             0.205  cooperative      concreteSlab        NaN
# 3  ...             0.177  condominium             brick        NaN
# 4  ...             0.043  condominium             brick    premium
#
#    hasParkingSpace  hasBalcony  hasElevator  hasSecurity  hasStorageRoom  \
# 0               no          no          yes           no              no
# 1               no          no           no           no              no
# 2               no         yes          yes          yes             yes
# 3               no         yes           no           no              no
# 4              yes         yes           no          yes             yes
#
#     price
# 0  420000
# 1  565000
# 2  429995
# 3  550000
# 4  607000
#
# [5 rows x 28 columns]

# %%
print(df_august.shape)
print(df_september.shape)
print(df_october.shape)
# Out:
# (18905, 28)
# (16997, 28)
# (16690, 28)

# %% [markdown]
# ## Concatenating Datasets

# %%
df_august['Month'] = 0
df_september['Month'] = 1
df_october['Month'] = 2

# %%
frames = [df_august, df_september, df_october]
df = pd.concat(frames)

# %% [markdown]
# <a id="section4"></a>
# # Data Analysis

# %%
# Shape of dataframe
df.shape
# Out:
# (52592, 29)

# %%
# Checking for missing values
df.isna().sum()
# Out:
# id                          0
# city                        0
# type                    11650
# squareMeters                0
# rooms                       0
# floor                    9527
# floorCount                750
# buildYear                9125
# latitude                    0
# longitude                   0
# centreDistance              0
# poiCount                    0
# schoolDistance             50
# clinicDistance            252
# postOfficeDistance         73
# kindergartenDistance       49
# restaurantDistance        154
# collegeDistance          1572
# pharmacyDistance           79
# ownership                   0
# buildingMaterial        20505
# condition               39819
# hasParkingSpace             0
# hasBalcony                  0
# hasElevator              2688
# hasSecurity                 0
# hasStorageRoom              0
# price                       0
# Month                       0
# dtype: int64

# %%
# Dropping id and columns which have a very high number of missing values, being impossible to apply techniques such as imputation
df.drop(['id','type', 'floor', 'buildYear', 'floorCount', 'condition', 'buildingMaterial'], axis=1, inplace=True)

# %%
df['Month'] = df['Month'].astype(str)

# %%
# Dropping remaining missing values
df_clean = df.dropna()

# %%
# Dropping duplicates if any
df_clean = df_clean.drop_duplicates().reset_index(drop=True)

# %%
df_clean.head(5)
# Out:
#        city  squareMeters  rooms   latitude  longitude  centreDistance  \
# 0  szczecin         36.00    2.0  53.442692  14.559690            2.15
# 1  szczecin         73.02    3.0  53.452222  14.553333            3.24
# 2  szczecin         87.60    3.0  53.435100  14.532900            2.27
# 3  szczecin         66.00    3.0  53.410278  14.503611            4.07
# 4  szczecin         63.30    3.0  53.463100  14.572800            4.48
#
#    poiCount  schoolDistance  clinicDistance  postOfficeDistance  ...  \
# 0      16.0           0.273           0.492               0.652  ...
# 1       9.0           0.275           0.672               0.367  ...
# 2      32.0           0.175           0.259               0.223  ...
# 3       1.0           0.218           1.690               0.504  ...
# 4      10.0           0.079           1.224               0.737  ...
#
#    collegeDistance  pharmacyDistance    ownership  hasParkingSpace hasBalcony  \
# 0            1.404             0.205  cooperative               no        yes
# 1            1.857             0.280  condominium               no         no
# 2            0.310             0.087  condominium              yes        yes
# 3            2.138             0.514  condominium               no         no
# 4            0.377             0.745  cooperative              yes        yes
#
#   hasElevator hasSecurity hasStorageRoom   price Month
# 0         yes          no            yes  395995     0
# 1          no          no             no  565000     0
# 2          no          no            yes  640000     0
# 3          no          no             no  759000     0
# 4          no          no            yes  499000     0
#
# [5 rows x 22 columns]

# %%
df_clean.shape
# Out:
# (47506, 22)

# %%
# Cell in case you want to save the new and clean dataframe to csv.
# df_clean = pd.to_csv('df_all_clean.csv', index=None)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47506 entries, 0 to 47505
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   city                  47506 non-null  object
#  1   squareMeters          47506 non-null  float64
#  2   rooms                 47506 non-null  float64
#  3   latitude              47506 non-null  float64
#  4   longitude             47506 non-null  float64
#  5   centreDistance        47506 non-null  float64
#  6   poiCount              47506 non-null  float64
#  7   schoolDistance        47506 non-null  float64
#  8   clinicDistance        47506 non-null  float64
#  9   postOfficeDistance    47506 non-null  float64
#  10  kindergartenDistance  47506 non-null  float64
#  11  restaurantDistance    47506 non-null  float64
#  12  collegeDistance       47506 non-null  float64
#  13  pharmacyDistance      47506 non-null  float64
#  14  ownership             47506 non-null  object
#  15  hasParkingSpace       47506 non-null  object
#  16  hasBalcony            47506 non-null  object
#  17  hasElevator           47506 non-null  object
#  18  hasSecurity           47506 non-null  object
#  19  hasStorageRoom        47506 non-null  object
#  20  price                 47506 non-null  int64
#  21  Month                 47506 non-null  object
# dtypes: float64(13), int64(1), object(8)
# memory usage: 8.0+ MB

# %%
df_clean.describe()
# Out:
#        squareMeters         rooms      latitude     longitude  centreDistance  \
# count  47506.000000  47506.000000  47506.000000  47506.000000    47506.000000
# mean      58.789410      2.681367     52.005544     19.554647        4.256220
# std       21.162648      0.906604      1.326269      1.758668        2.774684
# min       25.000000      1.000000     49.982455     14.462282        0.020000
# 25%       44.500000      2.000000     51.111463     18.545830        2.000000
# 50%       55.000000      3.000000     52.189120     19.916695        3.880000
# 75%       68.700000      3.000000     52.401888     20.997650        5.980000
# max      150.000000      6.000000     54.571600     23.207128       16.940000
#
#            poiCount  schoolDistance  clinicDistance  postOfficeDistance  \
# count  47506.000000    47506.000000    47506.000000        47506.000000
# mean      20.332421        0.389294        0.944394            0.493386
# std       23.153186        0.387557        0.845882            0.421304
# min        0.000000        0.004000        0.001000            0.001000
# 25%        7.000000        0.173000        0.358000            0.237000
# 50%       14.000000        0.286000        0.672000            0.387000
# 75%       24.000000        0.456000        1.219000            0.611000
# max      208.000000        4.472000        4.996000            4.585000
#
#        kindergartenDistance  restaurantDistance  collegeDistance  \
# count          47506.000000        47506.000000     47506.000000
# mean               0.346157            0.330838         1.460527
# std                0.360640            0.382405         1.102505
# min                0.002000            0.001000         0.006000
# 25%                0.156000            0.117000         0.596000
# 50%                0.262000            0.232000         1.139000
# 75%                0.410000            0.411000         2.089000
# max                4.680000            4.269000         5.000000
#
#        pharmacyDistance         price
# count      47506.000000  4.750600e+04
# mean           0.337976  7.134202e+05
# std            0.375233  3.533328e+05
# min            0.001000  1.512000e+05
# 25%            0.145000  4.700000e+05
# 50%            0.238000  6.480000e+05
# 75%            0.398000  8.580000e+05
# max            4.242000  2.500000e+06

# %% [markdown]
# ## Selecting Numerical and Categorical Columns

# %%
num_cols = df_clean.select_dtypes([np.number]).columns
df_nums = df_clean[num_cols].reset_index(drop=True)

# %%
cat_cols = df_clean.select_dtypes(['object']).columns
df_cats = df_clean[cat_cols].reset_index(drop=True)

# %% [markdown]
# <a id="section5"></a>
# # Data Visualization

# %% [markdown]
# ## Univariate Analysis - Box Plots

# %%
features = num_cols.to_list()
plt.figure(figsize=(15,5))
for i in range(0, len(features)):
    plt.subplot(2, 7, i + 1)
    sns.boxplot(y = df_clean[features[i]], color = 'magenta', orient = 'v')
    plt.tight_layout()

# %% [markdown]
# - It's important to notice that although boxplot indicates outliers, some of them seem to be natural values and should leave them as it is.

# %% [markdown]
# ## Univariate Analysis - Dist Plots

# %%
features = num_cols.to_list()
plt.figure(figsize = (20, 10))
for i in range(0, len(features)):
    plt.subplot(5, 3, i+1)
    sns.histplot(x = df_clean[features[i]], kde = True, color = 'green')
    plt.tight_layout()

# %% [markdown]
# - Most columns seem to be skewed, which needs to be corrected later.

# %% [markdown]
# ## Univariate Analysis - Violin Plots

# %%
plt.figure(figsize=(15,10))
features = num_cols.to_list()
for i in range(0, len(features)):
    plt.subplot(3, 5, i+1)
    sns.violinplot(y = df_clean[features[i]], color = 'yellow', orient = 'v')
    plt.tight_layout()

# %% [markdown]
# ## Univariate Analysis - Count Plot (Categorical)

# %%
plt.figure(figsize=(15,10))
for i in range(0, len(df_cats.columns)):
    plt.subplot(4, 3, i+1)
    ax = sns.countplot(y = df_clean[df_cats.columns[i]], palette = 'BuPu', orient = 'v')
    ax.set_xlim(0,df_clean[df_cats.columns[i]].value_counts().max()+df_clean[df_cats.columns[i]].value_counts().max()*0.2)
    ax.bar_label(ax.containers[0]);
    plt.tight_layout()

# %% [markdown]
# - Some of the categorical columns are way too imbalanced.

# %% [markdown]
# ## Bivariate Analysis - Correlation Map

# %%
df_nums.corr()
# Out:
#                       squareMeters     rooms  latitude  longitude  \
# squareMeters              1.000000  0.823454  0.019918  -0.008834
# rooms                     0.823454  1.000000  0.020927   0.010483
# latitude                  0.019918  0.020927  1.000000  -0.208511
# longitude                -0.008834  0.010483 -0.208511   1.000000
# centreDistance            0.077953  0.076015  0.067688   0.199924
# poiCount                  0.014797 -0.018446 -0.031397   0.028391
# schoolDistance            0.061593  0.070778  0.144596  -0.094491
# clinicDistance            0.004529  0.036103  0.101040  -0.068975
# postOfficeDistance        0.041154  0.049730  0.093426  -0.038926
# kindergartenDistance      0.054183  0.055580  0.183060  -0.134209
# restaurantDistance        0.014935  0.045107  0.143036  -0.103319
# collegeDistance           0.050457  0.065654  0.119145  -0.006732
# pharmacyDistance          0.049010  0.060456  0.135767  -0.049718
# price                     0.631668  0.489853  0.016830   0.204092
#
#                       centreDistance  poiCount  schoolDistance  \
# squareMeters                0.077953  0.014797        0.061593
# rooms                       0.076015 -0.018446        0.070778
# latitude                    0.067688 -0.031397        0.144596
# longitude                   0.199924  0.028391       -0.094491
# centreDistance              1.000000 -0.448479        0.278505
# poiCount                   -0.448479  1.000000       -0.323400
# schoolDistance              0.278505 -0.323400        1.000000
# clinicDistance              0.409028 -0.372230        0.527001
# postOfficeDistance          0.237292 -0.339967        0.669175
# kindergartenDistance        0.099567 -0.211151        0.711942
# restaurantDistance          0.216064 -0.379885        0.674199
# collegeDistance             0.548856 -0.441988        0.423134
# pharmacyDistance            0.246426 -0.325230        0.726965
# price                       0.136581  0.169016        0.012972
#
#                       clinicDistance  postOfficeDistance  \
# squareMeters                0.004529            0.041154
# rooms                       0.036103            0.049730
# latitude                    0.101040            0.093426
# longitude                  -0.068975           -0.038926
# centreDistance              0.409028            0.237292
# poiCount                   -0.372230           -0.339967
# schoolDistance              0.527001            0.669175
# clinicDistance              1.000000            0.448623
# postOfficeDistance          0.448623            1.000000
# kindergartenDistance        0.403683            0.642564
# restaurantDistance          0.501685            0.688399
# collegeDistance             0.502656            0.326807
# pharmacyDistance            0.480539            0.740413
# price                      -0.117423           -0.019484
#
#                       kindergartenDistance  restaurantDistance  \
# squareMeters                      0.054183            0.014935
# rooms                             0.055580            0.045107
# latitude                          0.183060            0.143036
# longitude                        -0.134209           -0.103319
# centreDistance                    0.099567            0.216064
# poiCount                         -0.211151           -0.379885
# schoolDistance                    0.711942            0.674199
# clinicDistance                    0.403683            0.501685
# postOfficeDistance                0.642564            0.688399
# kindergartenDistance              1.000000            0.678931
# restaurantDistance                0.678931            1.000000
# collegeDistance                   0.261575            0.328281
# pharmacyDistance                  0.767473            0.765873
# price                            -0.020406           -0.129634
#
#                       collegeDistance  pharmacyDistance     price
# squareMeters                 0.050457          0.049010  0.631668
# rooms                        0.065654          0.060456  0.489853
# latitude                     0.119145          0.135767  0.016830
# longitude                   -0.006732         -0.049718  0.204092
# centreDistance               0.548856          0.246426  0.136581
# poiCount                    -0.441988         -0.325230  0.169016
# schoolDistance               0.423134          0.726965  0.012972
# clinicDistance               0.502656          0.480539 -0.117423
# postOfficeDistance           0.326807          0.740413 -0.019484
# kindergartenDistance         0.261575          0.767473 -0.020406
# restaurantDistance           0.328281          0.765873 -0.129634
# collegeDistance              1.000000          0.353746  0.007602
# pharmacyDistance             0.353746          1.000000 -0.012585
# price                        0.007602         -0.012585  1.000000

# %%
corr_df = df_nums.corr()

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(corr_df, cmap = 'Blues', annot = True, fmt = '.2f')
plt.xticks(rotation=45);

# %%
df_clean[df_cats.columns] = df_clean[df_cats.columns].apply(LabelEncoder().fit_transform)

# %%
df_clean.head()
# Out:
#    city  squareMeters  rooms   latitude  longitude  centreDistance  poiCount  \
# 0    12         36.00    2.0  53.442692  14.559690            2.15      16.0
# 1    12         73.02    3.0  53.452222  14.553333            3.24       9.0
# 2    12         87.60    3.0  53.435100  14.532900            2.27      32.0
# 3    12         66.00    3.0  53.410278  14.503611            4.07       1.0
# 4    12         63.30    3.0  53.463100  14.572800            4.48      10.0
#
#    schoolDistance  clinicDistance  postOfficeDistance  ...  collegeDistance  \
# 0           0.273           0.492               0.652  ...            1.404
# 1           0.275           0.672               0.367  ...            1.857
# 2           0.175           0.259               0.223  ...            0.310
# 3           0.218           1.690               0.504  ...            2.138
# 4           0.079           1.224               0.737  ...            0.377
#
#    pharmacyDistance  ownership  hasParkingSpace  hasBalcony  hasElevator  \
# 0             0.205          1                0           1            1
# 1             0.280          0                0           0            0
# 2             0.087          0                1           1            0
# 3             0.514          0                0           0            0
# 4             0.745          1                1           1            0
#
#    hasSecurity  hasStorageRoom   price  Month
# 0            0               1  395995      0
# 1            0               0  565000      0
# 2            0               1  640000      0
# 3            0               0  759000      0
# 4            0               1  499000      0
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(df_clean.corr(), cmap = 'Blues', annot = True, fmt = '.2f')
plt.xticks(rotation=45);

# %% [markdown]
# <a id="section6"></a>
# # Machine Learning

# %% [markdown]
# ## Feature Selection

# %%
# Dropping low correlation columns (interestingly, some of them have high multicollinearity)
df_clean.drop(['schoolDistance','latitude', 'postOfficeDistance',
               'kindergartenDistance', 'collegeDistance', 'pharmacyDistance', 'hasBalcony','Month'], axis=1, inplace=True)

# %%
# Dropping rooms column because it has a high multicolinearity with squareMeters columns
df_clean.drop(['rooms'], axis=1, inplace=True)

# %% [markdown]
# ### Using Random Forest Classifier to Check the Most Important Features

# %%
X = df_clean.loc[:, df_clean.columns != 'price']
y = df_clean['price'].values

# %%
clf = RandomForestClassifier(n_estimators=10, random_state=0, max_depth=9, n_jobs=-1)

clf.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=9, n_estimators=10, n_jobs=-1, random_state=0)

# %%
feature_scores = pd.Series(clf.feature_importances_, index=X.columns).sort_values(ascending=False)

feature_scores
# Out:
# squareMeters          0.214433
# longitude             0.174062
# centreDistance        0.143809
# clinicDistance        0.110131
# poiCount              0.104650
# restaurantDistance    0.093936
# city                  0.063081
# hasElevator           0.027054
# hasStorageRoom        0.023288
# hasParkingSpace       0.017887
# ownership             0.015525
# hasSecurity           0.012145
# dtype: float64

# %%
plt.barh(X.columns, clf.feature_importances_)
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ### Using X1

# %%
X1 = df_clean.loc[:, df_clean.columns != 'price']
y1 = df_clean['price'].values

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.25, random_state = 42)

# %%
scaler = StandardScaler()

# %%
X1_train_scaled = scaler.fit_transform(X1_train)
X1_test_scaled = scaler.fit_transform(X1_test)

# %%
model = linear_model.LinearRegression(fit_intercept = True)

# %%
model_v1_lm = model.fit(X1_train_scaled, y1_train)

# %%
# Calcula a métrica R2 do nosso modelo
r2_score(y1_test, model_v1_lm.fit(X1_train_scaled, y1_train).predict(X1_test_scaled))
# Out:
# 0.5784683510199164

# %% [markdown]
# ### Using X2

# %%
X2 = df_clean[['squareMeters', 'longitude', 'centreDistance']]
y2 = df_clean['price']

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size = 0.25, random_state = 42)

# %%
X2_train_scaled = scaler.fit_transform(X2_train)
X2_test_scaled = scaler.fit_transform(X2_test)

# %%
model_v2_lm = model.fit(X2_train_scaled, y2_train)

# %%
# Calculating the R2 metric
r2_score(y2_test, model_v2_lm.fit(X2_train_scaled, y2_train).predict(X2_test_scaled))
# Out:
# 0.4333271662417286

# %% [markdown]
# - X2 had lower R2 score, but it's a way simpler model (containing less predictor variables), which makes it more generalizable

# %% [markdown]
# ## Random Forest

# %%
# Creating Random Forest Model
rf1 = RandomForestRegressor(n_estimators = 100, min_samples_leaf = 10, random_state = 101, n_jobs=-1, max_depth=9, oob_score=True)

# %% [markdown]
# ### Using X1

# %%
model_rf_v1 = rf1.fit(X1_train_scaled, y1_train)

# %%
prediction = model_rf_v1.predict(X1_test_scaled)

# %%
mean_squared_error(y1_test, prediction)
# Out:
# 21699119252.977818

# %%
mean_absolute_error(y1_test, prediction)
# Out:
# 104124.77819386296

# %%
r2_score(y1_test, prediction)
# Out:
# 0.8213139408228141

# %% [markdown]
# ### Using X2

# %%
model_rf_v2 = rf1.fit(X2_train_scaled, y2_train)

# %%
prediction = model_rf_v2.predict(X2_test_scaled)

# %%
mean_squared_error(y2_test, prediction)
# Out:
# 24105717361.022766

# %%
mean_absolute_error(y2_test, prediction)
# Out:
# 109498.70372417054

# %%
r2_score(y1_test, prediction)
# Out:
# 0.8014962916852431

# %% [markdown]
# - X1 and X2 had similar performances. X2 being a simpler model, it would be chosen.

# %% [markdown]
# ### Finding the best n_estimator

# %%
N_estimators = [5,50,100,200,500,1000]
R2_score = []
for n_estimator in N_estimators:
    model = RandomForestRegressor(n_estimators = n_estimator,max_depth = 9)
    model.fit(X2_train_scaled, y2_train)
    prediction = model.predict(X2_test_scaled)
    r2_calc = r2_score(y2_test, prediction)
    R2_score.append(r2_calc)
    print(f'For {n_estimator} n_estimator and the R2 score is: ', r2_calc)
# Out:
# For 5 n_estimator and the R2 score is:  0.7995920937071053
# For 50 n_estimator and the R2 score is:  0.8040268262531554
# For 100 n_estimator and the R2 score is:  0.8050519758801282
# For 200 n_estimator and the R2 score is:  0.8058470973430498
# For 500 n_estimator and the R2 score is:  0.8050965972366647
# For 1000 n_estimator and the R2 score is:  0.8053705839128851

# %%
fig, ax = plt.subplots()
ax.plot(N_estimators, R2_score,c='g')
for i, txt in enumerate(np.round(R2_score,5)):
    ax.annotate((N_estimators[i],str(txt)), (N_estimators[i],R2_score[i]))
plt.grid()
plt.title("R2 Score for each Estimator")
plt.xlabel("Estimator i's")
plt.ylabel("Score measure")
plt.show()

# %% [markdown]
# ### Using GridSearchCV for Hyperparameter Tuning

# %%
#param_grid = { 
#    'n_estimators': [25, 50, 100, 150, 200], 
#    'max_features': ['sqrt', 'log2', None], 
#    'max_depth': [3, 6, 9], 
#    'max_leaf_nodes': [3, 6, 9], 
#}


#grid_search = GridSearchCV(RandomForestRegressor(), 
#                           param_grid=param_grid) 
#grid_search.fit(X1_train_scaled, y1_train) 
#print(grid_search.best_estimator_)

# %%
#model_grid = RandomForestRegressor(max_depth=9,
#                                   max_features=1.0,
#                                   max_leaf_nodes=None,
#                                   n_estimators=200,
#                                   random_state=10)

# %%
#model_grid.fit(X2_train_scaled, y2_train) 
#y_pred_grid = model_grid.predict(X2_test_scaled)

# %%
#r2_score(y2_test, y_pred_grid)

# %% [markdown]
# ## XGBRegressor

# %%
model = XGBRegressor(n_estimators=200, max_depth=6, eval_metric=["auc", "error", "error@0.6"])

# %%
model.fit(X2_train_scaled, y2_train)
# Out:
# C:\Users\Victor\anaconda3\lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False,
#              eval_metric=['auc', 'error', 'error@0.6'], feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=6, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=200, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
prediction = model.predict(X2_test_scaled)

# %%
print(r2_score(y2_test, prediction))
# Out:
# 0.8343673508356864

# %%
print(mean_squared_error(y2_test, prediction))

print(mean_absolute_error(y2_test, prediction))
# Out:
# 20113950819.40425
# 98931.0213385114

# %% [markdown]
# <a id="section7"></a>
# # Conclusion

# %% [markdown]
# - X2 selected features not always returned better evaluation metrics, but being a way simpler model, it should be chosen since its more generalizable.
# - Among all the algorithms XGBoost Regressor had better results.
# - Tuning hyperparameters might return better results.
